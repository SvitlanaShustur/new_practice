# %% [markdown]
# ## ML Introduction. Date: 2026-01-06
#
# **Topics**:
# > 1. Introduction in ML
# > 2. Scikit-Learning
# > 3. Type of machine learning
# > 4. Example of ML-models
#
# **Materials**:
# > 1. [Scikit-learn](https://scikit-learn.org/stable/)

# %% [markdown]
# ![](https://s.dou.ua/storage-files/image4_G3msWXQ.png)

# %% [markdown]
# #### Machine Learning — це підхід, при якому:
# > ми не задаємо правила вручну \
# > модель навчається на історичних даних \
# > і робить прогноз або класифікацію для нових ситуацій
#
# Історичні дані + ціль -> навчена модель -> прогноз
#
# **Типові задачі:**
# > churn \
# > fraud \
# > персоналізація \
# > прогноз доходу \
# > сегментація клієнтів
#
#
# ##### Приклад: Відтік користувачів
#
# **Аналітика:**
# > 12% користувачів пішли \
# > частіше йдуть без оплати \
# > частіше йдуть після 7 днів
#
# **ML:**
# > дає список користувачів \
# > з імовірністю відтоку для кожного \
# > ДО того, як вони підуть

# %% [markdown]
# **Аналітика:**
# > працює з історичними даними \
# > пояснює причини \
# > знаходить патерни \
# > формує гіпотези \
# > будує метрики та дашборди
#
# Приклад: Користувачі, які не активували триал за 3 дні, мають churn 45%
#
# **ML дозволяє:**
# > узагальнити аналітичні закономірності \
# > працювати на рівні кожного обʼєкта \
# > робити прогноз до події \
#
# Приклад: Для кожного користувача порахувати ймовірність churn на наступні 7 днів
#
#
# **ML не потрібен, якщо:**
# > правила прості і стабільні \
# > рішення приймаються рідко \
# > даних мало \
# > немає дії після прогнозу
#
# Приклад: Якщо користувач не оплатив за 30 днів -> вважаємо його churn

# %% [markdown]
# ![](https://images.ctfassets.net/wp1lcwdav1p1/3KsRz6gDJhJiw39LhjlsKJ/efa6a39ff85c49cbe4d8b815068cab53/Data_Science_vs._Machine_Learning.png?w=1500&q=60)

# %% [markdown]
# ![](https://cdn.letterdrop.co/images/2024/5/20/types-of-machine-learning_2tev.webp)

# %% [markdown]
# | Критерій | Є target                 | Немає target          |
# | -------- | ------------------------ | --------------------- |
# | Тип      | Supervised learning      | Unsupervised learning |
# | Логіка   | Навчання на відповідях   | Пошук структури       |
# | Контроль | Якість вимірюється чітко | Якість відносна       |

# %% [markdown]
# Target - це змінна:
# - ми хочемо передбачити
# - яка відома в історичних даних
# - яка визначає форму задачі

# %% [markdown]
# #### Supervised Learning
# Supervised learning — це навчання функції:
#
# 𝑓(𝑋) -> 𝑦
#
# де:
# X — набір ознак (features) \
# y — цільова змінна (target)
#
# ---
# ##### Regression (регресія)
#
# **Коли використовується:**
# - target — число
#
# **Приклади:**
# - LTV користувача
# - дохід
# - час доставки
# - кількість звернень у support
#
# ---
# ##### Classification (класифікація)
#
# **Коли використовується:**
# - target — клас / категорія
# - або подія (так / ні)
#
# **Приклади:**
# - churn / not churn
# - fraud / normal
# - купить / не купить
#
# **Модель:**
# > не знає бізнесу \
# > не знає причин \
# > мінімізує помилку між прогнозом і target
#
#
# ##### Модель оптимізує математику, а не бізнес-результат
# ---
# ![](https://media.geeksforgeeks.org/wp-content/uploads/20250129121636823249/classification-vs-regression.webp)

# %% [markdown]
# #### Unsupervised Learning
#
# ##### Clustering (кластеризація)
# - розбити обʼєкти на групи
# - за схожістю ознак
#
# **Приклади:**
# - сегментація користувачів
# - групування контенту
# - поведінкові патерни
#
#
#
# ##### Anomaly Detection (пошук аномалій)
# - знайти нетипові обʼєкти
# - відносно основної маси даних
#
# **Приклади:**
# - fraud
# - технічні збої
# - різкі сплески активності
#
#
#
#
# **Модель:**
# - не знає, що добре, а що погано
# - шукає математичну компактність
# - сильно залежить від ознак і масштабу
#
#
#
#
# Supervised -> прогноз відомого
#
# Unsupervised -> пошук невідомого
#
# _**Target визначає тип навчання**_

# %% [markdown]
# ### Матриця фіч
# > Ця схема таблиці ясно показує, що інформацію можна представити у вигляді двовимірного числового масиву або матриці, яку ми називатимемо *матрицею фіч*.
#
# > За традицією, ця матриця характеристик часто зберігається у змінній з іменем *x*.
#
# > Матриця фіч передбачається двовимірною з формою **[n_samples, n_features]**, і найчастіше міститься в масиві NumPy або Pandas DataFrame, хоча деякі моделі Scikit-learn також приймають розріджені матриці SciPy.
#
# > Вибірки(рядки) завжди відносяться до окремих об'єктів, що описуються набором даних.
#
# > Ознаки (стовпці) завжди відносяться до окремих спостережень, які кількісно/якісно описують кожен зразок.
# Ознаки зазвичай мають речове значення, але в деяких випадках можуть бути булевими або дискретними.

# %% [markdown]
# ### Знайомство зі Scikit-Learning
# > scikit-learn - проєкт з відкритим вихідним кодом, це означає, що його можна вільно використовувати і поширювати, і будь-яка людина може легко отримати вихідний код, щоб побачити, що відбувається "за лаштунками".
#
# > Проєкт scikit-learn постійно розвивається і вдосконалюється, і в нього дуже активна спільнота користувачів. Він містить низку сучасних алгоритмів машинного навчання, а також повну документацію щодо кожного алгоритму. scikit-learn - дуже популярний інструмент і найвідоміша пітонівська бібліотека для
# машинного навчання. Її широко використовують у промисловості та науці, а в інтернеті є багатий вибір навчальних матеріалів і прикладів програмного коду. scikit-learn чудово працює з низкою інших наукових інструментів Python.
#
# > Розуміння принципів роботи та використання scikit-learn - важливе, але є кілька інших бібліотек, які розширять ваш досвід. scikit-learn базується на двох пітонівських бібліотеках для наукових обчислень NumPy і SciPy. Крім NumPy і SciPy ми будемо використовувати pandas і matplotlib.

# %% [markdown]
# > У машинному навчанні з учителем нам потрібно побудувати модель на навчальних даних, а потім отримати точні прогнози для нових даних, які ще не зустрічалися, і які мають такі самі характеристики, що й використаний нами навчальний набір. Якщо модель може видавати точні прогнози на даних, які раніше не зустрічалися, ми говоримо, що модель має здатність узагальнювати (generalize) результат на тестові дані. Нам необхідно побудувати модель, яка матиме максимальну узагальнювальну здатність.
# > Зазвичай ми будуємо модель таким чином, щоб вона давала точні прогнози на навчальному наборі. Якщо навчальний і тестовий набори мають багато спільного між собою, можна очікувати, що модель буде точною і на тестовому наборі. Однак у деяких випадках цього не відбувається.

# %% [markdown]
# ![](https://miro.medium.com/0%2A9X2zABY7kHZguqcB.PNG)

# %% [markdown]
# ##### Від бізнес-питання до ML-задачі
#
#
# Як зменшити відтік користувачів?
#
# **Неправильно:**
#
# Побудуємо модель churn
#
# **Правильно:**
#
# Визначити користувачів,
# які з високою ймовірністю підуть
# протягом N днів,
# щоб встигнути зробити дію X
#
#
# _**ML-задача завжди має бути привʼязана до дії**_

# %% [markdown]
# ##### Unit of Prediction (одиниця прогнозу)
# Unit of prediction — це:
# > обʼєкт \
# > для якого модель робить один прогноз
#
# ##### Target (цільова змінна)
# Target - це:
# > те, що модель має передбачити \
# > формалізована бізнес-подія
#
#
# ##### Prediction Horizon (горизонт прогнозу)
# Horizon — це:
# > проміжок часу \
# > між моментом прогнозу \
# > і моментом події
#
# ##### Action (дія після прогнозу)
#
# Для кожного [unit]
# на дату T
# передбачити [target]
# протягом [horizon]
# щоб виконати [action]
#
#
# Для кожного користувача
# щодня
# передбачити ймовірність churn
# протягом 30 днів
# щоб запустити retention-кампанію
#
# ---
# Модель — це функція, яка перетворює features у прогноз
#
# > **Underfitting:** модель занадто проста, не бачить закономірності \
# > **Overfitting:** модель занадто складна, запамʼятала шум

# %% [markdown]
# ##### k-Nearest Neighbors (kNN)
#
# **kNN:**
# - не навчає явну формулу
# - зберігає всі тренувальні точки
#
# **для нового обʼєкта:**
# - знаходить k найближчих сусідів
# - дивиться, які в них target
# - голосує / усереднює
#
# Користувач схожий на цих 5 — з них 4 пішли ->  високий ризик churn
#
# Коли kNN має сенс
# - маленькі або середні датасети
# - інтуїтивна логіка схожості
# - погано масштабується
# -  дуже чутливий до масштабу ознак

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split

import pandas as pd
import numpy as np 
import seaborn  as sns
import matplotlib.pyplot as plt

# %matplotlib inline 
sns.set('notebook')

import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
X = df.drop(columns="species")
y = df["species"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled[0:5], X_train[0:5]
# Out:
# (array([[ 1.79213839, -0.60238047,  1.31532306,  0.92095427],
#         [ 2.14531053, -0.60238047,  1.65320421,  1.05135487],
#         [-0.4446185 , -1.50797259, -0.03620155, -0.25265117],
#         [ 0.26172578, -0.60238047,  0.13273902,  0.13855064],
#         [-0.4446185 , -1.28157456,  0.13273902,  0.13855064]]),
#       sepal_length  sepal_width  petal_length  petal_width
#  130           7.4          2.8           6.1          1.9
#  122           7.7          2.8           6.7          2.0
#  81            5.5          2.4           3.7          1.0
#  71            6.1          2.8           4.0          1.3
#  89            5.5          2.5           4.0          1.3)

# %%
KNeighborsClassifier?
# Out:
# Init signature:
# KNeighborsClassifier(
#     n_neighbors=5,
#     *,
#     weights='uniform',
#     algorithm='auto',
#     leaf_size=30,
#     p=2,
#     metric='minkowski',
#     metric_params=None,
#     n_jobs=None,
# )
# Docstring:
# Classifier implementing the k-nearest neighbors vote.
#
# Read more in the :ref:`User Guide <classification>`.
#
# Parameters
# ----------
# n_neighbors : int, default=5
#     Number of neighbors to use by default for :meth:`kneighbors` queries.
#
# weights : {'uniform', 'distance'}, callable or None, default='uniform'
#     Weight function used in prediction.  Possible values:
#
#     - 'uniform' : uniform weights.  All points in each neighborhood
#       are weighted equally.
#     - 'distance' : weight points by the inverse of their distance.
#       in this case, closer neighbors of a query point will have a
#       greater influence than neighbors which are further away.
#     - [callable] : a user-defined function which accepts an
# ...

# %%
inertia = []
N = 25
for k in range(1, N):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    inertia.append(accuracy_score(y_test, y_pred))

plt.plot(range(1, N), inertia, marker="o")
plt.show()

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.pairplot(df, hue = 'species');

# %%
df.sample(2)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 42            4.4          3.2           1.3          0.2     setosa
# 128           6.4          2.8           5.6          2.1  virginica

# %%
knn.predict([[6.4, 2.8, 5.6, 2.1]])
# Out:
# array(['virginica'], dtype=object)

# %%
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train_scaled, y_train)

y_pred = knn.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9736842105263158

# %%
print([1, 2, 3, 4])

# %%
# import graphviz

# %%
##### Decision Tree
df = sns.load_dataset("titanic")

df = df[["survived", "pclass", "sex", "age", "fare"]]
df = df.dropna()

# %%
df["sex"] = df["sex"].map({"male": 0, "female": 1})

# %%
df['sex'].unique()
# Out:
# array([0, 1])

# %%
X = df.drop(columns="survived")
y = df["survived"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# %%
DecisionTreeClassifier?
# Out:
# Init signature:
# DecisionTreeClassifier(
#     *,
#     criterion='gini',
#     splitter='best',
#     max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_features=None,
#     random_state=None,
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     class_weight=None,
#     ccp_alpha=0.0,
#     monotonic_cst=None,
# )
# Docstring:
# A decision tree classifier.
#
# Read more in the :ref:`User Guide <tree>`.
#
# Parameters
# ----------
# criterion : {"gini", "entropy", "log_loss"}, default="gini"
#     The function to measure the quality of a split. Supported criteria are
#     "gini" for the Gini impurity and "log_loss" and "entropy" both for the
#     Shannon information gain, see :ref:`tree_mathematical_formulation`.
#
# splitter : {"best", "random"}, default="best"
#     The strategy used to choose the split at each node. Supported
#     strategies are "best" to choose the best split and "random" to choose
# ...

# %%
tree = DecisionTreeClassifier(
    max_depth=4,
    min_samples_leaf=30,
    random_state=42
)

tree.fit(X_train, y_train)

y_pred_proba = tree.predict_proba(X_test)[:, 1]

# %%
X_test[0:5]
# Out:
#      pclass  sex   age     fare
# 386       3    0   1.0  46.9000
# 817       2    0  31.0  37.0042
# 74        3    0  32.0  56.4958
# 422       3    0  29.0   7.8750
# 90        3    0  29.0   8.0500

# %%
y_pred_proba
# Out:
# array([0.38235294, 0.09375   , 0.09375   , 0.22      , 0.22      ,
#        0.54054054, 0.09375   , 0.93333333, 0.28947368, 0.3       ,
#        0.98305085, 0.98305085, 0.52380952, 0.93333333, 0.90625   ,
#        0.52380952, 0.03921569, 0.98305085, 0.09375   , 0.03921569,
#        0.03921569, 0.28947368, 0.22      , 0.03921569, 0.28947368,
#        0.28947368, 0.11      , 0.90625   , 0.54054054, 0.98305085,
#        0.03921569, 0.52380952, 0.11      , 0.11      , 0.09375   ,
#        0.03921569, 0.90625   , 0.11      , 0.03921569, 0.09375   ,
#        0.54054054, 0.11      , 0.03921569, 0.22      , 0.93333333,
#        0.03921569, 0.3       , 0.03921569, 0.98305085, 0.22      ,
#        0.52380952, 0.90625   , 0.98305085, 0.98305085, 0.28947368,
#        0.11      , 0.03921569, 0.54054054, 0.93333333, 0.90625   ,
#        0.98305085, 0.22      , 0.3       , 0.03921569, 0.03921569,
#        0.52380952, 0.22      , 0.3       , 0.38235294, 0.3       ,
# ...

# %%
from sklearn.tree import plot_tree

# %%
tree.feature_importances_
# Out:
# array([0.22569963, 0.63434242, 0.07294432, 0.06701363])

# %%
plt.figure(figsize=(20,10))
plot_tree(
    tree, feature_names=tree.feature_names_in_, class_names=tree.class_weight, filled=True
)
plt.show()

# %%
##### Регресія

df = sns.load_dataset("tips")
df.head()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

X = df[["total_bill", "size"]]
y = df["tip"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
print("MAE:", mean_absolute_error(y_test, y_pred))

# %%
for feature, coef in zip(X.columns, lr.coef_):
    print(feature, coef)
